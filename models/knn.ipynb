# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.metrics import confusion_matrix, precision_score, recall_score

# %%
df = pd.read_csv("diabetes_dataset.csv")
df
# Out:
#        age  gender ethnicity education_level  income_level employment_status  \
# 0       58    Male     Asian      Highschool  Lower-Middle          Employed
# 1       48  Female     White      Highschool        Middle          Employed
# 2       60    Male  Hispanic      Highschool        Middle        Unemployed
# 3       74  Female     Black      Highschool           Low           Retired
# 4       46    Male     White        Graduate        Middle           Retired
# ...    ...     ...       ...             ...           ...               ...
# 99995   46    Male     Other        Graduate  Upper-Middle        Unemployed
# 99996   41  Female     White        Graduate        Middle          Employed
# 99997   57  Female     Black       No formal  Upper-Middle          Employed
# 99998   47  Female     Black      Highschool  Lower-Middle           Retired
# 99999   52  Female     White    Postgraduate        Middle          Employed
#
#       smoking_status  alcohol_consumption_per_week  \
# 0              Never                             0
# 1             Former                             1
# 2              Never                             1
# 3              Never                             0
# 4              Never                             1
# ...              ...                           ...
# 99995         Former                             1
# 99996          Never                             3
# 99997         Former                             4
# 99998          Never                             3
# 99999          Never                             1
#
#        physical_activity_minutes_per_week  diet_score  ...  hdl_cholesterol  \
# 0                                     215         5.7  ...               41
# 1                                     143         6.7  ...               55
# 2                                      57         6.4  ...               66
# 3                                      49         3.4  ...               50
# 4                                     109         7.2  ...               52
# ...                                   ...         ...  ...              ...
# 99995                                 136         8.3  ...               45
# 99996                                  76         8.8  ...               55
# 99997                                 121         9.9  ...               50
# 99998                                  52         5.9  ...               68
# 99999                                 248         2.7  ...               31
#
#        ldl_cholesterol  triglycerides  glucose_fasting  glucose_postprandial  \
# 0                  160            145              136                   236
# 1                   50             30               93                   150
# 2                   99             36              118                   195
# 3                   79            140              139                   253
# 4                  125            160              137                   184
# ...                ...            ...              ...                   ...
# 99995              150            116              113                   109
# 99996              123            146               96                   146
# 99997              111            184               93                   132
# 99998               91            116              106                   117
# 99999              183             87               91                   142
#
#        insulin_level  hba1c  diabetes_risk_score  diabetes_stage  \
# 0               6.36   8.18                 29.6          Type 2
# 1               2.00   5.63                 23.0     No Diabetes
# 2               5.07   7.51                 44.7          Type 2
# 3               5.28   9.03                 38.2          Type 2
# 4              12.74   7.20                 23.5          Type 2
# ...              ...    ...                  ...             ...
# 99995          14.58   5.55                 26.0    Pre-Diabetes
# 99996           9.02   5.97                 24.4    Pre-Diabetes
# 99997           2.57   5.21                 27.6     No Diabetes
# 99998           9.81   5.53                 26.4    Pre-Diabetes
# 99999          15.93   5.73                 27.9    Pre-Diabetes
#
#        diagnosed_diabetes
# 0                       1
# 1                       0
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 99995                   0
# 99996                   0
# 99997                   0
# 99998                   0
# 99999                   0
#
# [100000 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['age', 'gender', 'ethnicity', 'education_level', 'income_level',
#        'employment_status', 'smoking_status', 'alcohol_consumption_per_week',
#        'physical_activity_minutes_per_week', 'diet_score',
#        'sleep_hours_per_day', 'screen_time_hours_per_day',
#        'family_history_diabetes', 'hypertension_history',
#        'cardiovascular_history', 'bmi', 'waist_to_hip_ratio', 'systolic_bp',
#        'diastolic_bp', 'heart_rate', 'cholesterol_total', 'hdl_cholesterol',
#        'ldl_cholesterol', 'triglycerides', 'glucose_fasting',
#        'glucose_postprandial', 'insulin_level', 'hba1c', 'diabetes_risk_score',
#        'diabetes_stage', 'diagnosed_diabetes'],
#       dtype='object')

# %%
cols_to_drop = ['education_level', 'employment_status', 'income_level', 'waist_to_hip_ratio', 'ldl_cholesterol', 'hdl_cholesterol', 'hba1c', 'diabetes_risk_score', 'smoking_status', 'ethnicity', 'cardiovascular_history']
df = df.drop(columns=cols_to_drop)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'alcohol_consumption_per_week',
#        'physical_activity_minutes_per_week', 'diet_score',
#        'sleep_hours_per_day', 'screen_time_hours_per_day',
#        'family_history_diabetes', 'hypertension_history', 'bmi', 'systolic_bp',
#        'diastolic_bp', 'heart_rate', 'cholesterol_total', 'triglycerides',
#        'glucose_fasting', 'glucose_postprandial', 'insulin_level',
#        'diabetes_stage', 'diagnosed_diabetes'],
#       dtype='object')

# %%
# Separate features and target
target_col = "diagnosed_diabetes"
X = df.drop(target_col, axis=1)
y = df[target_col].astype(bool)

# %%
'''Given a list of features, create a KNN model and evaluate it.'''
def knn_model(features: list, model_num: int, num_neighbors: int, metric: str):
  x = X[features]

  # split the set into test and train
  X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

  # Construct the pipeline
  preproc = make_column_transformer(
      (StandardScaler(), features), # all candidate features are numerical
      remainder='drop'
  )
  pipeline = make_pipeline(
      preproc,
      KNeighborsClassifier(n_neighbors=num_neighbors, metric=metric)
  )

  pipeline.fit(X_train, y_train)
  predictions = pipeline.predict(X_test)

  conf_mat = pd.DataFrame(
    confusion_matrix(y_test, predictions),
    columns = pipeline.classes_,
    index = pipeline.classes_)
  precision = precision_score(y_test, predictions, average='binary')
  recall = recall_score(y_test, predictions, average='binary')
  
  return {
    'model_num': model_num,
    'num_neighbors': num_neighbors,
    'metric': metric,
    'precision': precision,
    'recall': recall,
    'conf_mat': conf_mat
  }

# %%
def test_knn_model(features: list, n: int):
    results = {}
    for i in range(3, 100, 2):
        res = knn_model(features, n, num_neighbors=i, metric='minkowski')
        results[res['num_neighbors']] = res

    best_k = max(results, key=lambda k: results[k]['recall'])
    best_result = results[best_k]

    print(f"Model #{best_result['model_num']}, {best_result['num_neighbors']}-neighbors, '{best_result['metric']}' metric")
    print(f"Precision: {best_result['precision']:.4f}\nRecall: {best_result['recall']:.4f}\n")
    print(f"Confusion Matrix:\n{best_result['conf_mat']}\n\n")

# %%
# SEGMENT FOR MODEL 1
candidate_features_1 = ['age', 'alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'bmi', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial', 'insulin_level']
test_knn_model(candidate_features_1, 1)

# Up to 100 neighbors test: 
# num neighbors: 89
# Precision: 0.8798
# Recall: 0.8463
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # SEGMENT FOR MODEL 1
#       2 candidate_features_1 = ['age', 'alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'bmi', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial', 'insulin_level']
# ----> 3 test_knn_model(candidate_features_1, 1)
#       5 # Up to 100 neighbors test:
#       6 # num neighbors: 89
#       7 # Precision: 0.8798
#       8 # Recall: 0.8463
#
# Cell In[8], line 4, in test_knn_model(features, n)
#       2 results = {}
#       3 for i in range(3, 100, 2):
# ----> 4     res = knn_model(features, n, num_neighbors=i, metric='minkowski')
#       5     results[res['num_neighbors']] = res
#       7 best_k = max(results, key=lambda k: results[k]['recall'])
#
# Cell In[7], line 19, in knn_model(features, model_num, num_neighbors, metric)
#      13 pipeline = make_pipeline(
#      14     preproc,
#      15     KNeighborsClassifier(n_neighbors=num_neighbors, metric=metric)
#      16 )
#      18 pipeline.fit(X_train, y_train)
# ---> 19 predictions = pipeline.predict(X_test)
#      21 conf_mat = pd.DataFrame(
#      22   confusion_matrix(y_test, predictions),
#      23   columns = pipeline.classes_,
#      24   index = pipeline.classes_)
#      25 precision = precision_score(y_test, predictions, average='binary')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\pipeline.py:788, in Pipeline.predict(self, X, **params)
#     786     for _, name, transform in self._iter(with_final=False):
#     787         Xt = transform.transform(Xt)
# --> 788     return self.steps[-1][1].predict(Xt, **params)
#     790 # metadata routing enabled
#     791 routed_params = process_routing(self, "predict", **params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\neighbors\_classification.py:274, in KNeighborsClassifier.predict(self, X)
#     271         return self.classes_[np.argmax(probabilities, axis=1)]
#     272     # In that case, we do not need the distances to perform
#     273     # the weighting so we do not compute them.
# --> 274     neigh_ind = self.kneighbors(X, return_distance=False)
#     275     neigh_dist = None
#     276 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\neighbors\_base.py:923, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     918     if issparse(X):
#     919         raise ValueError(
#     920             "%s does not work with sparse matrices. Densify the data, "
#     921             "or set algorithm='brute'" % self._fit_method
#     922         )
# --> 923     chunked_results = Parallel(n_jobs, prefer="threads")(
#     924         delayed(self._tree.query)(X[s], n_neighbors, return_distance)
#     925         for s in gen_even_slices(X.shape[0], n_jobs)
#     926     )
#     927 else:
#     928     raise ValueError("internal: _fit_method not recognized")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# SEGMENT FOR MODEL 2
candidate_features_2 = ['age', 'alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'bmi', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial']
test_knn_model(candidate_features_2, 2)

# Up to 100 neighbors test: 
# num neighbors: 99
# Precision: 0.8837
# Recall: 0.8424
# Out:
# Model #2, 99-neighbors, 'minkowski' metric
# Precision: 0.8837
# Recall: 0.8424
#
# Confusion Matrix:
#        False  True
# False   6670   1330
# True    1891  10109

# %%
# SEGMENT FOR MODEL 3
candidate_features_3 = ['alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'bmi', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial']
test_knn_model(candidate_features_3, 3)

# Up to 100 neighbors test: 
# num neighbors: 99
# Precision: 0.8860
# Recall: 0.8397
# Out:
# Model #3, 99-neighbors, 'minkowski' metric
# Precision: 0.8860
# Recall: 0.8397
#
# Confusion Matrix:
#        False  True
# False   6704   1296
# True    1924  10076

# %%
# SEGMENT FOR MODEL 4
candidate_features_4 = ['physical_activity_minutes_per_week', 'bmi', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial']
test_knn_model(candidate_features_4, 4)

# Up to 100 neighbors test: 
# num neighbors: 99
# Precision: 0.8955
# Recall: 0.8358
# Out:
# Model #4, 87-neighbors, 'minkowski' metric
# Precision: 0.8955
# Recall: 0.8358
#
# Confusion Matrix:
#        False  True
# False   6829   1171
# True    1970  10030

# %%
# SEGMENT FOR MODEL 5
candidate_features_5 = ['alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'bmi', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial', 'insulin_level']
test_knn_model(candidate_features_5, 5)

# Up to 100 neighbors test: 
# num neighbors: 99
# Precision: 0.8856
# Recall: 0.8441

# Up to 250 neighbors test:
# num neighbors: 245
# Precision: 0.8819
# Recall: 0.8476
# Out:
# Model #5, 245-neighbors, 'minkowski' metric
# Precision: 0.8819
# Recall: 0.8476
#
# Confusion Matrix:
#        False  True
# False   6638   1362
# True    1829  10171

# %%
# SEGMENT FOR MODEL 6
candidate_features_6 = ['alcohol_consumption_per_week', 'physical_activity_minutes_per_week', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial', 'insulin_level']
test_knn_model(candidate_features_6, 6)

# Up to 100 neighbors test: 
# num neighbors: 99
# Precision: 0.8875
# Recall: 0.8397
# Out:
# Model #6, 89-neighbors, 'minkowski' metric
# Precision: 0.8875
# Recall: 0.8397
#
# Confusion Matrix:
#        False  True
# False   6723   1277
# True    1924  10076

# %%
# SEGMENT FOR MODEL 7
candidate_features_7 = ['physical_activity_minutes_per_week', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial']
test_knn_model(candidate_features_7, 7)

# Up to 100 neighbors test: 
# num neighbors: 75
# Precision: 0.8966
# Recall: 0.8327
# Out:
# Model #7, 75-neighbors, 'minkowski' metric
# Precision: 0.8966
# Recall: 0.8327
#
# Confusion Matrix:
#        False  True
# False   6848   1152
# True    2008   9992

# %%
# SEGMENT FOR MODEL 8
candidate_features_8 = ['systolic_bp', 'glucose_fasting', 'glucose_postprandial']
test_knn_model(candidate_features_8, 8)

# Up to 100 neighbors test: 
# num neighbors: 99
# Precision: 0.8993
# Recall: 0.8297
# Out:
# Model #8, 99-neighbors, 'minkowski' metric
# Precision: 0.8993
# Recall: 0.8297
#
# Confusion Matrix:
#        False  True
# False   6885   1115
# True    2043   9957

# %%
# SEGMENT FOR MODEL 9
candidate_features_9 = ['bmi', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial']
test_knn_model(candidate_features_9, 9)

# Up to 100 neighbors test: 
# num neighbors: 93
# Precision: 0.8957
# Recall: 0.8342
# Out:
# Model #9, 93-neighbors, 'minkowski' metric
# Precision: 0.8957
# Recall: 0.8342
#
# Confusion Matrix:
#        False  True
# False   6834   1166
# True    1990  10010

# %%
# SEGMENT FOR MODEL 10
candidate_features_10 = ['diet_score', 'physical_activity_minutes_per_week', 'systolic_bp', 'glucose_fasting', 'glucose_postprandial']
test_knn_model(candidate_features_10, 10)

# Up to 100 neighbors test: 
# num neighbors: 99
# Precision: 0.8931
# Recall: 0.8359
# Out:
# Model #10, 99-neighbors, 'minkowski' metric
# Precision: 0.8931
# Recall: 0.8359
#
# Confusion Matrix:
#        False  True
# False   6799   1201
# True    1969  10031

# %%
# SEGMENT FOR MODEL 11
candidate_features_11 = ['physical_activity_minutes_per_week', 'bmi', 'glucose_fasting', 'glucose_postprandial']
test_knn_model(candidate_features_11, 11)

# Up to 100 neighbors test: 
# num neighbors: 91
# Precision: 0.8965
# Recall: 0.8319
# Out:
# Model #11, 91-neighbors, 'minkowski' metric
# Precision: 0.8965
# Recall: 0.8319
#
# Confusion Matrix:
#        False  True
# False   6848   1152
# True    2017   9983
